# %%
import pandas as pd
import numpy as np
import os
import time
import random
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from os.path import isfile, join
import time

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python')
random.seed(99)

# %%
allfiles = [f for f in os.listdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo') if isfile(join('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo', f))]

letras = ['2', '5']

filt_files = [idx for idx in allfiles if idx[0] == letras[0] or idx[0] == letras[1]]

filt_files
# Out:
# ['2500mil_fit10.csv',
#  '2500mil_fit5.csv',
#  '2500mil_fit6.csv',
#  '2500mil_fit7.csv',
#  '2500mil_fit8.csv',
#  '2500mil_fit9.csv',
#  '500mil_fit10.csv',
#  '500mil_fit5.csv',
#  '500mil_fit6.csv',
#  '500mil_fit7.csv',
#  '500mil_fit8.csv',
#  '500mil_fit9.csv',
#  '500_fit10.csv',
#  '500_fit5.csv',
#  '500_fit6.csv',
#  '500_fit7.csv',
#  '500_fit8.csv',
#  '500_fit9.csv',
#  '50mil_fit10.csv',
#  '50mil_fit5.csv',
#  '50mil_fit6.csv',
#  '50mil_fit7.csv',
#  '50mil_fit8.csv',
#  '50mil_fit9.csv',
#  '5mil_fit10.csv',
#  '5mil_fit5.csv',
#  '5mil_fit6.csv',
#  '5mil_fit7.csv',
#  '5mil_fit8.csv',
#  '5mil_fit9.csv']

# %%
runs = range(1, 6)

# %%
# # # FIT BASE # # # 
def fit5(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre)   
    
    return tiempos_list

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresion con fit5
fit5_files = [s for s in filt_files if "fit5" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit5.csv', '') for names in fit5_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit5(fit5_files[i - 1])

tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit5.csv', index=False)

# %%
# # # Fit 6 # # # 

def fit6(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB", "SITTRA"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB', 'SITTRA']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre)    
    return tiempos_list

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresio con fit6
fit6_files = [s for s in filt_files if "fit6" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit6.csv', '') for names in fit6_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit6(fit6_files[i - 1])
    
tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit6.csv', index=False)

# %%
# # # Fit 7 # # # 

def fit7(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB", "SITTRA", "ALFABET"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB', 'SITTRA', 'ALFABET']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre)    
    
    return tiempos_list

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresio con fit7
fit7_files = [s for s in filt_files if "fit7" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit7.csv', '') for names in fit7_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit7(fit7_files[i - 1])
    
tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit7.csv', index=False)

# %%
# # # Fit 8 # # # 

def fit8(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB", "SITTRA", "ALFABET", "AGUINALDO"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB', 
                  'SITTRA', 'ALFABET', 'AGUINALDO']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre)   
    
    return tiempos_list

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresio con fit7
fit8_files = [s for s in filt_files if "fit8" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit8.csv', '') for names in fit8_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit8(fit8_files[i - 1])
    
tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit8.csv', index=False)

# %%
# # # Fit 9 # # # 

def fit9(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB", "SITTRA", 
                         "ALFABET", "AGUINALDO", "VACACIONES"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB', 
                  'SITTRA', 'ALFABET', 'AGUINALDO', 'VACACIONES']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre) 
    
    return(tiempos_list)

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresio con fit7
fit9_files = [s for s in filt_files if "fit9" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit9.csv', '') for names in fit9_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit9(fit9_files[i - 1])
    
tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit9.csv', index=False)

# %%
# # # Fit 10 # # # 

def fit10(nombre_archivo):
    fit_data = pd.read_csv(nombre_archivo)
# Vector con todas las categorias
    vector_categorias = ["SEXO", "NIVACAD", "ENT_PAIS_TRAB", "SITTRA", 
                         "ALFABET", "AGUINALDO", "VACACIONES", "SERVICIO_MEDICO"]

    # Y las transformamos
    for columna in vector_categorias:
        fit_data[columna] = fit_data[columna].astype('category')
        
    x = fit_data[['HORTRA', 'SEXO', 'EDAD', 'NIVACAD', 'ENT_PAIS_TRAB', 
                  'SITTRA', 'ALFABET', 'AGUINALDO', 'VACACIONES', 'SERVICIO_MEDICO']]
    y = fit_data[['INGTRMEN']]
    
    # Los hacemos dummies 
    x = pd.get_dummies(data = x, drop_first = True)
    
    # Hacemos la regresión
    regr = linear_model.LinearRegression()
    
    tiempos_list = []
    for i in runs:
        start = time.time()
        # Ojo que regresa el coeficiente para la potencia mayor primero
        model = regr.fit(x, y)
        # Medimos el tiempo
        tiempo = time.time() - start
        tiempos_list.append(tiempo)
    
    # Guardamos los intercepts
    intercepts = model.intercept_
    # Guardamos los coeficientes de los resultados
    coeficientes = model.coef_
    coeficientes = np.transpose(coeficientes)

    intercepts = pd.DataFrame(intercepts)

    coeficientes = pd.DataFrame(coeficientes)

    # Los unimos
    resultados = np.vstack([intercepts, coeficientes])
    # Los guardamos
    nombre = 'Python_' + nombre_archivo 
    resultados = pd.DataFrame(resultados)
    resultados.to_csv(r"C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\" + nombre) 
    return tiempos_list

# %%
os.chdir('C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo')

# Ahora hacemos la regresio con fit7
fit10_files = [s for s in filt_files if "fit10" in s]

# Hagamos un df vacio para guardar los tiempos
names = [names.replace('_fit10.csv', '') for names in fit10_files]

res_dic = {}
for i in runs:
    res_dic[names[i - 1]] = fit10(fit10_files[i - 1])
    
tiempo_df = pd.DataFrame.from_dict(res_dic)
    
tiempo_df.to_csv(r'C:\\Users\\Valeria\\Tesis_Julia_con_R\\Censo\\Python\\timePython_Censo_fit10.csv', index=False)
